# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("data-jumlah-pelayanan-kesehatan-hewan-bulan-oktober-tahun-2021.csv")
x = dataset.iloc[:, [2,3]].values
y = dataset.iloc[:, -1].values

# %%
print(x)
# Out:
# [['Abortus' nan]
#  ['Abses' '1']
#  ['Acral Lick Dermatitis' '0']
#  ...
#  ['Urethritis' '0']
#  ['Uveitis' '0']
#  ['Vulnus' '0']]

# %%
print(y)
# Out:
# ['Vetoxy La. Vetadryl. Sulpidone. Hematodin'
#  'Cefotaxime.Dexamethason.Biosolamin.Septo Skin Spray'
#  'Bethamox. Vitol Ade. Vetadryl' ... 'PenStrep. Carosil'
#  'Limoxin . Dexa . Hematopan Biodin'
#  'Cefotaxime.Roborante.Dexamethason.Biosolamin. Enrofloxacin']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test, = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
print(x_train)
# Out:
# [['Hydroderma' nan]
#  ['Pasteurellosis' '0']
#  ['Suspek FLUTD' '0']
#  ...
#  ['Suspek EGC' nan]
#  ['Ginggivitis' '0']
#  ['Gangguan Syaraf Tulang Belakang' '0']]

# %%
print(x_test)
# Out:
# [['Enteritis' '0']
#  ['DIPHYLIDIASIS' '0']
#  ['Othematoma' nan]
#  ['Radang' '0']
#  ['Luka Trauma' '0']
#  ['Abses' '1']
#  ['RIP' nan]
#  ['Alergi' '0']
#  ['Ear mites' '0']
#  ['Suspek Calisivirus' '0']
#  ['Hyphocalsemia' '0']
#  ['Radang' '0']
#  ['Demam Non Spesifik' '0']
#  ['Sprain' '0']
#  ['Pullorum' '1']
#  ['Prolaps Bulbi' '0']
#  ['Stres fisiologis' '0']
#  ['Suspek Calisivirus' '0']
#  ['Suspek FUS' '0']
#  ['Demam Non Spesifik' '0']
#  ['Periodontitis' '0']
#  ['Operasi Kecil' '1']
#  ['Prolaps Uteri' '0']
#  ['Seizure' '0']
#  ['Seizure' '0']
#  ['Laminitis' '1']
#  ['Chlamydia' '0']
#  ['Chlamydia' '0']
#  ['Pyoderma' '0']
#  ['Hydroderma' '0']
#  ['Sprain' '0']
#  ['Ektoparasitosis' '0']
#  ['Pneumonia' '0']
#  ['Suspek FUS' '0']
#  ['Stomatitis' '0']
#  ['Tumor' '2']
#  ['Suspek Calisivirus' '19']
#  ['Suspek FUS' '0']
#  ['Anorexia' nan]
#  ['Pneumonia' '8']
#  ['Rhinitis' '0']
#  ['Gastritis' '1']
#  ['Metritis' '0']
#  ['Enteritis' nan]
#  ['Gigi Caries' '0']
#  ['Indigesti' '0']
#  ['Miositis' '0']
#  ['Urethritis' '0']
#  ['Radang' '0']
#  ['Endometritis' '0']
#  ['Tracheitis' '0']
#  ['Pyoderma' '0']
#  ['Miositis' '0']
#  ['FIC' '0']
#  ['Endophtalmitis' '0']
#  ['Abses' nan]
#  ['Uveitis' '0']
#  ['Tumor' nan]
#  ['Inflamasi' '0']
#  ['Myalgia' '0']
#  ['USG' '1']
#  ['Ginggivitis' '0']
#  ['Conjunctivitis' '0']
#  ['Scabies' nan]
#  ['FUC' '0']
#  ['Operasi Kecil' '1']
#  ['Diarrhea' '0']
#  ['Suspek FLUTD' '0']
#  ['Laringitis' '0']
#  ['Dermatophytosis' '0']
#  ['BEF' '0']
#  ['Bronkitis' '0']
#  ['Rhinotracheitis' '0']
#  ['Ginggivitis' '8']
#  ['Inkoordinasi Syaraf' '0']
#  ['Avitaminosis' '6']
#  ['Check Up' nan]
#  ['Otitis' '0']
#  ['Nebulizer' '0']
#  ['Suspek Chlamydiosis' '0']
#  ['Pulmonani' '0']
#  ['Myalgia' nan]
#  ['Suspek Rhinotracutis' '0']
#  ['Febris' '0']
#  ['Operasi Kecil' '0']
#  ['Abortus' '1']
#  ['Avitaminosis' '0']
#  ['Bronchopneumonia' '0']
#  ['Endometritis' '0']
#  ['Gastroenteritis' '0']
#  ['Suspek Pyometra' '1']
#  ['Acral Lick Dermatitis' '0']
#  ['Pullorum' '0']
#  ['Anorexia' '0']
#  ['Prolaps Bulbi' '0']
#  ['Endoparasit' '0']
#  ['Abortus' '0']
#  ['Bronkitis' '0']
#  ['Kornea ulser' '9']
#  ['Renal Failure' '0']
#  ['Myasis' '0']
#  ['Retensio Sec' '0']
#  ['Chlongiohepatitis' '0']
#  ['Pyometra' '0']
#  ['Chlamydia' '32']
#  ['Radang' '0']
#  ['Urethritis' '1']
#  ['Pemeriksaan' '0']
#  ['Suspek Pyometra' '0']
#  ['Endoparasit' '0']
#  ['Distokia' '0']
#  ['EGC' '0']
#  ['RIP' '0']
#  ['Luka Trauma' '0']
#  ['Anemia' '0']
#  ['Metritis' '0']
#  ['Vulnus' '0']
#  ['Mycoplasmosis' '0']
#  ['CKD' '0']
#  ['Rhinitis' '0']
#  ['Dermatophytosis' '0']
#  ['Bronchopneumonia' '0']
#  ['Suspek FUS' '0']
#  ['Pasteurellosis' '0']
#  ['Laringitis' '0']
#  ['Hyphocalsemia' '0']
#  ['Gastritis' '0']
#  ['FIP' '0']
#  ['Stomatitis' '0']
#  ['Fraktur' '0']
#  ['Otitis' '0']
#  ['Rhinitis' '0']
#  ['Inflamasi' '0']
#  ['Fraktur' nan]
#  ['Nebulizer' '36']
#  ['FIC' '0']
#  ['Prolaps Uteri' '0']
#  ['Kennel Cough' '0']
#  ['Hydroderma' '0']
#  ['Vulnus' '0']
#  ['Radang' '0']
#  ['Pyometra' '0']
#  ['Hernia ' '0']
#  ['Suspek Panleucopenia' '0']
#  ['Chlongiohepatitis' '0']
#  ['Prolaps anii' '0']
#  ['Suspek FUS' '17']
#  ['Pemeriksaan' '0']
#  ['Myasis' '0']
#  ['Avitaminosis' nan]
#  ['Gigi Caries' '0']
#  ['Malnutrisi' '0']
#  ['Rhinotracheitis' '0']
#  ['Distokia' '0']
#  ['Inflamasi' '0']
#  ['USG' '0']
#  ['Chlamydia' '0']
#  ['Myalgia' '0']
#  ['Avitaminosis' '2']
#  ['Ear mites' '0']
#  ['Heart Failure' nan]
#  ['Endometritis' '0']
#  ['Post partus' '1']
#  ['Endoparasit' nan]
#  ['Seizure' '0']
#  ['Anemia' '0']
#  ['Miositis' '0']
#  ['Trauma' '1']
#  ['Gangguan Syaraf Tulang Belakang' '0']
#  ['Miositis' nan]
#  ['Snot' '0']
#  ['Sprain' '0']
#  ['Pediculosis' nan]
#  ['Check Up' '0']
#  ['USG' '0']
#  ['Luka Trauma' '0']
#  ['Malnutrisi' '0']
#  ['Trauma' '0']
#  ['Endometritis' '0']
#  ['Dermatophytosis' '0']
#  ['Laminitis' '0']
#  ['Scabies' '0']
#  ['USG' '14']
#  ['Enteritis' '0']
#  ['Gastritis' '0']
#  ['CRD' nan]
#  ['Vulnus' '38']
#  ['Scabies' '0']
#  ['Suspek EGC' '0']
#  ['Bloat' '1']
#  ['Bronkitis' '0']
#  ['Jamur' '0']
#  ['Laminitis' '0']
#  ['CKD' '1']
#  ['CKD' '0']
#  ['Sporotrichosis' '0']
#  ['Suspek Calisivirus' '0']
#  ['Suspek Pyometra' nan]
#  ['Operasi Besar' '0']
#  ['Demam Non Spesifik' '0']
#  ['Pullorum' '0']
#  ['Laminitis' '0']
#  ['Snot' nan]
#  ['DIPHYLIDIASIS' '0']
#  ['Hyphocalsemia' '0']
#  ['Dislokasi' '0']
#  ['Operasi Besar' '1']
#  ['Stres fisiologis' '0']
#  ['Anemia' '0']
#  ['RIP' '0']
#  ['Inflamasi' '0']
#  ['Renal Failure' '0']
#  ['Seizure' '3']
#  ['Ektoparasitosis' '0']
#  ['Dermatophytosis' '32']
#  ['Indigesti' '0']
#  ['Miositis' '0']
#  ['Gigi Caries' '0']
#  ['Necrotic' '0']
#  ['CKD' '0']
#  ['Bloat' '0']
#  ['Bloat' nan]
#  ['Conjunctivitis' '0']
#  ['Flu' '0']
#  ['Operasi Besar' nan]
#  ['Intoksikasi ' '0']
#  ['Suspek Panleucopenia' '0']
#  ['Suspect FRV' '0']
#  ['FHV / FRV' nan]
#  ['FCV' '0']
#  ['Demam Non Spesifik' '0']
#  ['USG' '0']
#  ['Endoparasit' '1']
#  ['Distemper' '0']
#  ['FLUTD' '0']
#  ['Heart Failure' '0']
#  ['Conjunctivitis' '0']
#  ['Kennel Cough' '0']
#  ['Pyoderma' '0']
#  ['Pediculosis' '0']
#  ['Scabies' '98']
#  ['FLUTD' '0']
#  ['FUC' '0']
#  ['Stomatitis' '0']
#  ['FIC' '0']
#  ['Conjunctivitis' '0']
#  ['Jamur' '0']
#  ['Suspek EGC' '0']
#  ['Dislokasi' '0']
#  ['Acral Lick Dermatitis' '0']
#  ['Mastitis' '0']
#  ['Kornea ulser' nan]
#  ['Paraplegia' nan]
#  ['Endophtalmitis' '0']
#  ['Laringitis' nan]
#  ['Panleukopenia' '0']]

# %%
print(y_train)
# Out:
# ['R/ Furosemide. Heptasan. Seloxy'
#  'Inj / Baytril. Vetadryl . Hematopan . Biodin'
#  'Bethamox. Hematodin. Vetadryl' 'Interflox. glucortine'
#  'Septri. Hematopan. Biodin. Vetadryl'
#  'Ivermectin.Ketoconazole.Enrofloxacin' 'Castran'
#  ' Betamox. Vetadryl . Hematopan' 'Interflox. Vitol. Carosil'
#  'Vetoxy La. Vetadryl. Sulpidone. Hematodin'
#  '

#  'Cefotaxime.Ampicillin.Aminophyllin.Biosolamin. Dexamethason'
#  'Enrofloxacin. Biodin'
#  'Inj / Betamox. Vetadryl. Hematopan R/ Drontal Cat'
#  'Calcidex Plus. Vit Ade' 'Bethamox. Hematodin. Dexamethazone'
#  'Ketamine. Silazin. Bethamox. Hematodin'
#  'Betamox. Vetadryl. Hematopan . Biodin ' 'Hematodin' nan
#  'Glucortin. Vetadryl' 'Biodin. Hematodin' 'Castran'
#  'Ivermectin. Roborante' 'Sebazole. Chlorhexidine. Vetadryl'
#  'Hematodin. Vetadryl. Vit B1' 'Dexamethason. Prednisone'
#  'Interflox. Tolfedine' 'Inj/ Cefazidime . Biodin . Dexametasone'
#  'Ketosteril. Lenal Ace. Ornipural' 'Trocar. Antibloat. Tympanol. Vit B1'
#  'Trocar. Antibloat. Tympanol. Vit B1'
#  'Dexamethason. Chloramphenicol Salep Mata'
#  'Cefotaxime.Ampicillin.Aminophyllin.Biosolamin.Fluimucil'
#  'Ketamine. Silazin. Bethamox. Hematodin'
#  'Bethamox. Hematodin. Vetadryl. Biodin' 'Bethamox. Hematodin. Vetadryl'
#  'Vitamin B-Comp. Dexametazone/Spiradin. Hematodin'
#  'Vitamin C . Vetadryl. Hematopan. Biodin'
#  'Inj / Vetadryl . Aminophyline . Vetoxy . Hematopan . Biodin R/ Infus Rl Subkutan '
#  'Bethamox. Hematodin. Sulpidone'
#  'Cek kehamilan. penyakit dalam dan reproduksi'
#  'Doxycycline. Clindamycin. Ivermectine. Selamectine'
#  'Amoxiclav. biodin. livron bplek'
#  'Pasang Cateter.Ampicillin.Aminophyllin.Biosolamin.'
#  'Inj / Betamox. Vetadryl' 'Dexamethason. Chloramphenicol Salep Mata'
#  'Betamox. Vetadryl ' 'Cephalexin. Dexamethasone. Vit.C'
#  'Baytril. Aminophilin' 'Ivermectin. Biosolamin.Inmunair'
#  'Pasang Cateter.Ampicillin.Aminophyllin.Biosolamin.'
#  'Betamox. Tolfedin . Hematopan . Biodin' 'Betamox. Biodin' 'Flunixin'
#  'Dexamethason. Chloramphenicol Salep Mata'
#  'Ivermectin.Ketoconazole.Enrofloxacin' 'Glucortine. PenStrep. Ivomec'
#  'Bethamox. Hematodin. Dexamethazone' 'Bethamox. Vitol Ade. Vetadryl'
#  'Betamox. Dexa. ' 'Gentamicin. Tetracicline. Ofloxacin. Vit A'
#  'Nacl Fisiologis' 'Inj/ Betamox. Tolfedine . Hematopan . Biodin '
#  'Cefotaxime.Ampicillin.Aminophyllin.Biosolamin. Dexamethason'
#  'Betamox. Vetadryl. Hematopan. Biodin']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-436d450d7687> in <module>()
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc = StandardScaler()
# ----> 3 x_train = sc.fit_transform(x_train)
#       4 x_test = sc.transform(x_test)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
#     808     def partial_fit(self, X, y=None, sample_weight=None):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     845             dtype=FLOAT_DTYPES,
#     846             force_all_finite="allow-nan",
# --> 847             reset=first_call,
#     848         )
#     849         n_features = X.shape[1]
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# ValueError: could not convert string to float: 'Hydroderma'

# %%
print(x_train)
# Out:
# [['Hydroderma' nan]
#  ['Pasteurellosis' '0']
#  ['Suspek FLUTD' '0']
#  ...
#  ['Suspek EGC' nan]
#  ['Ginggivitis' '0']
#  ['Gangguan Syaraf Tulang Belakang' '0']]

# %%
print(x_test)
# Out:
# [['Enteritis' '0']
#  ['DIPHYLIDIASIS' '0']
#  ['Othematoma' nan]
#  ['Radang' '0']
#  ['Luka Trauma' '0']
#  ['Abses' '1']
#  ['RIP' nan]
#  ['Alergi' '0']
#  ['Ear mites' '0']
#  ['Suspek Calisivirus' '0']
#  ['Hyphocalsemia' '0']
#  ['Radang' '0']
#  ['Demam Non Spesifik' '0']
#  ['Sprain' '0']
#  ['Pullorum' '1']
#  ['Prolaps Bulbi' '0']
#  ['Stres fisiologis' '0']
#  ['Suspek Calisivirus' '0']
#  ['Suspek FUS' '0']
#  ['Demam Non Spesifik' '0']
#  ['Periodontitis' '0']
#  ['Operasi Kecil' '1']
#  ['Prolaps Uteri' '0']
#  ['Seizure' '0']
#  ['Seizure' '0']
#  ['Laminitis' '1']
#  ['Chlamydia' '0']
#  ['Chlamydia' '0']
#  ['Pyoderma' '0']
#  ['Hydroderma' '0']
#  ['Sprain' '0']
#  ['Ektoparasitosis' '0']
#  ['Pneumonia' '0']
#  ['Suspek FUS' '0']
#  ['Stomatitis' '0']
#  ['Tumor' '2']
#  ['Suspek Calisivirus' '19']
#  ['Suspek FUS' '0']
#  ['Anorexia' nan]
#  ['Pneumonia' '8']
#  ['Rhinitis' '0']
#  ['Gastritis' '1']
#  ['Metritis' '0']
#  ['Enteritis' nan]
#  ['Gigi Caries' '0']
#  ['Indigesti' '0']
#  ['Miositis' '0']
#  ['Urethritis' '0']
#  ['Radang' '0']
#  ['Endometritis' '0']
#  ['Tracheitis' '0']
#  ['Pyoderma' '0']
#  ['Miositis' '0']
#  ['FIC' '0']
#  ['Endophtalmitis' '0']
#  ['Abses' nan]
#  ['Uveitis' '0']
#  ['Tumor' nan]
#  ['Inflamasi' '0']
#  ['Myalgia' '0']
#  ['USG' '1']
#  ['Ginggivitis' '0']
#  ['Conjunctivitis' '0']
#  ['Scabies' nan]
#  ['FUC' '0']
#  ['Operasi Kecil' '1']
#  ['Diarrhea' '0']
#  ['Suspek FLUTD' '0']
#  ['Laringitis' '0']
#  ['Dermatophytosis' '0']
#  ['BEF' '0']
#  ['Bronkitis' '0']
#  ['Rhinotracheitis' '0']
#  ['Ginggivitis' '8']
#  ['Inkoordinasi Syaraf' '0']
#  ['Avitaminosis' '6']
#  ['Check Up' nan]
#  ['Otitis' '0']
#  ['Nebulizer' '0']
#  ['Suspek Chlamydiosis' '0']
#  ['Pulmonani' '0']
#  ['Myalgia' nan]
#  ['Suspek Rhinotracutis' '0']
#  ['Febris' '0']
#  ['Operasi Kecil' '0']
#  ['Abortus' '1']
#  ['Avitaminosis' '0']
#  ['Bronchopneumonia' '0']
#  ['Endometritis' '0']
#  ['Gastroenteritis' '0']
#  ['Suspek Pyometra' '1']
#  ['Acral Lick Dermatitis' '0']
#  ['Pullorum' '0']
#  ['Anorexia' '0']
#  ['Prolaps Bulbi' '0']
#  ['Endoparasit' '0']
#  ['Abortus' '0']
#  ['Bronkitis' '0']
#  ['Kornea ulser' '9']
#  ['Renal Failure' '0']
#  ['Myasis' '0']
#  ['Retensio Sec' '0']
#  ['Chlongiohepatitis' '0']
#  ['Pyometra' '0']
#  ['Chlamydia' '32']
#  ['Radang' '0']
#  ['Urethritis' '1']
#  ['Pemeriksaan' '0']
#  ['Suspek Pyometra' '0']
#  ['Endoparasit' '0']
#  ['Distokia' '0']
#  ['EGC' '0']
#  ['RIP' '0']
#  ['Luka Trauma' '0']
#  ['Anemia' '0']
#  ['Metritis' '0']
#  ['Vulnus' '0']
#  ['Mycoplasmosis' '0']
#  ['CKD' '0']
#  ['Rhinitis' '0']
#  ['Dermatophytosis' '0']
#  ['Bronchopneumonia' '0']
#  ['Suspek FUS' '0']
#  ['Pasteurellosis' '0']
#  ['Laringitis' '0']
#  ['Hyphocalsemia' '0']
#  ['Gastritis' '0']
#  ['FIP' '0']
#  ['Stomatitis' '0']
#  ['Fraktur' '0']
#  ['Otitis' '0']
#  ['Rhinitis' '0']
#  ['Inflamasi' '0']
#  ['Fraktur' nan]
#  ['Nebulizer' '36']
#  ['FIC' '0']
#  ['Prolaps Uteri' '0']
#  ['Kennel Cough' '0']
#  ['Hydroderma' '0']
#  ['Vulnus' '0']
#  ['Radang' '0']
#  ['Pyometra' '0']
#  ['Hernia ' '0']
#  ['Suspek Panleucopenia' '0']
#  ['Chlongiohepatitis' '0']
#  ['Prolaps anii' '0']
#  ['Suspek FUS' '17']
#  ['Pemeriksaan' '0']
#  ['Myasis' '0']
#  ['Avitaminosis' nan]
#  ['Gigi Caries' '0']
#  ['Malnutrisi' '0']
#  ['Rhinotracheitis' '0']
#  ['Distokia' '0']
#  ['Inflamasi' '0']
#  ['USG' '0']
#  ['Chlamydia' '0']
#  ['Myalgia' '0']
#  ['Avitaminosis' '2']
#  ['Ear mites' '0']
#  ['Heart Failure' nan]
#  ['Endometritis' '0']
#  ['Post partus' '1']
#  ['Endoparasit' nan]
#  ['Seizure' '0']
#  ['Anemia' '0']
#  ['Miositis' '0']
#  ['Trauma' '1']
#  ['Gangguan Syaraf Tulang Belakang' '0']
#  ['Miositis' nan]
#  ['Snot' '0']
#  ['Sprain' '0']
#  ['Pediculosis' nan]
#  ['Check Up' '0']
#  ['USG' '0']
#  ['Luka Trauma' '0']
#  ['Malnutrisi' '0']
#  ['Trauma' '0']
#  ['Endometritis' '0']
#  ['Dermatophytosis' '0']
#  ['Laminitis' '0']
#  ['Scabies' '0']
#  ['USG' '14']
#  ['Enteritis' '0']
#  ['Gastritis' '0']
#  ['CRD' nan]
#  ['Vulnus' '38']
#  ['Scabies' '0']
#  ['Suspek EGC' '0']
#  ['Bloat' '1']
#  ['Bronkitis' '0']
#  ['Jamur' '0']
#  ['Laminitis' '0']
#  ['CKD' '1']
#  ['CKD' '0']
#  ['Sporotrichosis' '0']
#  ['Suspek Calisivirus' '0']
#  ['Suspek Pyometra' nan]
#  ['Operasi Besar' '0']
#  ['Demam Non Spesifik' '0']
#  ['Pullorum' '0']
#  ['Laminitis' '0']
#  ['Snot' nan]
#  ['DIPHYLIDIASIS' '0']
#  ['Hyphocalsemia' '0']
#  ['Dislokasi' '0']
#  ['Operasi Besar' '1']
#  ['Stres fisiologis' '0']
#  ['Anemia' '0']
#  ['RIP' '0']
#  ['Inflamasi' '0']
#  ['Renal Failure' '0']
#  ['Seizure' '3']
#  ['Ektoparasitosis' '0']
#  ['Dermatophytosis' '32']
#  ['Indigesti' '0']
#  ['Miositis' '0']
#  ['Gigi Caries' '0']
#  ['Necrotic' '0']
#  ['CKD' '0']
#  ['Bloat' '0']
#  ['Bloat' nan]
#  ['Conjunctivitis' '0']
#  ['Flu' '0']
#  ['Operasi Besar' nan]
#  ['Intoksikasi ' '0']
#  ['Suspek Panleucopenia' '0']
#  ['Suspect FRV' '0']
#  ['FHV / FRV' nan]
#  ['FCV' '0']
#  ['Demam Non Spesifik' '0']
#  ['USG' '0']
#  ['Endoparasit' '1']
#  ['Distemper' '0']
#  ['FLUTD' '0']
#  ['Heart Failure' '0']
#  ['Conjunctivitis' '0']
#  ['Kennel Cough' '0']
#  ['Pyoderma' '0']
#  ['Pediculosis' '0']
#  ['Scabies' '98']
#  ['FLUTD' '0']
#  ['FUC' '0']
#  ['Stomatitis' '0']
#  ['FIC' '0']
#  ['Conjunctivitis' '0']
#  ['Jamur' '0']
#  ['Suspek EGC' '0']
#  ['Dislokasi' '0']
#  ['Acral Lick Dermatitis' '0']
#  ['Mastitis' '0']
#  ['Kornea ulser' nan]
#  ['Paraplegia' nan]
#  ['Endophtalmitis' '0']
#  ['Laringitis' nan]
#  ['Panleukopenia' '0']]

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-ea243097c0d3> in <module>()
#       1 from sklearn.naive_bayes import GaussianNB
#       2 classifier = GaussianNB()
# ----> 3 classifier.fit(x_train, y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     242             Returns the instance itself.
#     243         """
# --> 244         y = self._validate_data(y=y)
#     245         return self._partial_fit(
#     246             X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
# --> 569             y = _check_y(y, **check_params)
#     570             out = y
#     571         else:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _check_y(y, multi_output, y_numeric)
#     992     else:
#     993         y = column_or_1d(y, warn=True)
# --> 994         _assert_all_finite(y)
#     995         _ensure_no_complex_data(y)
#     996     if y_numeric and y.dtype.kind == "O":
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     120     elif X.dtype == np.dtype("object") and not allow_nan:
#     121         if _object_dtype_isnan(X).any():
# --> 122             raise ValueError("Input contains NaN")
#     123
#     124
#
# ValueError: Input contains NaN

# %%
y_pred = classifier.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-14-6d05000dfd70> in <module>()
# ----> 1 y_pred = classifier.predict(x_test)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/naive_bayes.py in predict(self, X)
#      79             Predicted target values for X.
#      80         """
# ---> 81         check_is_fitted(self)
#      82         X = self._check_X(X)
#      83         jll = self._joint_log_likelihood(X)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1220
#    1221     if not fitted:
# -> 1222         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1223
#    1224
#
# NotFittedError: This GaussianNB instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-630348889997> in <module>()
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 cm = confusion_matrix(y_test, y_pred)
#       3 print(cm)
#
# NameError: name 'y_pred' is not defined

# %%
from matplotlib.colors import ListedColormap
x_set, y_set = x_train, y_train
x1, x2 = np.meshgrid(np.arange(start = x_set[:, 0].min()-1, stop = x_set[:, 0].max() + 1, step=0.01), 
                     np.arange(start = x_set[:, 1].min()-1, stop = x_set[:, 0].max() + 1, step=0.01))
plt.contour(x1,x2, classifier.predict(np.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape),
            alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(x1.min(), x1.max())
plt.ylim(x2.min(), x2.max())
for i, j in enumerate (np.unique(y_set)):
  plt.scatter(x_set[y_set == j, 0], x_set[y_set==j, 1],
              c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Data dengan Naive Bayes (Data Training)') 
plt.xlabel('diagnosa') 
plt.ylabel('pengobatan') 
plt.legend()
plt.show()

# %%
from matplotlib.colors import ListedColormap
x_set, y_set = x_test, y_test
x1, x2 = np.meshgrid(np.arange(start = x_set[:, 0].min()-1, stop = x_set[:, 0].max() + 1, step=0.01), 
                     np.arange(start = x_set[:, 1].min()-1, stop = x_set[:, 0].max() + 1, step=0.01))
plt.contour(x1,x2, classifier.predict(np.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape),
            alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(x1.min(), x1.max())
plt.ylim(x2.min(), x2.max())
for i, j in enumerate (np.unique(y_set)):
  plt.scatter(x_set[y_set == j, 0], x_set[y_set==j, 1],
              c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Data dengan Naive Bayes (Data Training)') 
plt.xlabel('diagnosa') 
plt.ylabel('pengobatan') 
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-67d58c08f2ea> in <module>()
#       1 from matplotlib.colors import ListedColormap
#       2 x_set, y_set = x_test, y_test
# ----> 3 x1, x2 = np.meshgrid(np.arange(start = x_set[:, 0].min()-1, stop = x_set[:, 0].max() + 1, step=0.01),
#       4                      np.arange(start = x_set[:, 1].min()-1, stop = x_set[:, 0].max() + 1, step=0.01))
#       5 plt.contour(x1,x2, classifier.predict(np.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape),
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
